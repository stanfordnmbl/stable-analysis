# %%
from pathlib import Path
Path('features').mkdir(exist_ok=True)

# %% [markdown]
# STANDING EYES-CLOSED

# %%
from get_features_standing_ec import get_features_standing_ec
get_features_standing_ec()

# %% [markdown]
# RISE-TO-TOES

# %%
from get_features_rtt import get_features_rtt
get_features_rtt()

# %% [markdown]
# SEMI-TANDEM

# %%
from get_features_semi_tandem import get_features_semi_tandem
get_features_semi_tandem()

# %% [markdown]
# TANDEM

# %%
from get_features_tandem import get_features_tandem
get_features_tandem()

# %% [markdown]
# SINGLE-LEG-STANCE EYES-CLOSED

# %%
from get_features_sls_ec import get_features_sls_ec
get_features_sls_ec()

# %% [markdown]
# SINGLE-LEG-STANCE RISE-TO-TOES

# %%
from get_features_sls_rtt import get_features_sls_rtt
get_features_sls_rtt()

# %% [markdown]
# SINGLE-LEG-STANCE RISE-TO-TOES EYES-CLOSED

# %%
from get_features_sls_rtt_ec import get_features_sls_rtt_ec
get_features_sls_rtt_ec()

# %% [markdown]
# FUNCTIONAL REACH TEST

# %%
from get_features_frt import get_features_frt
get_features_frt()

# %% [markdown]
# 5 TIMES SIT TO STAND

# %%
from get_features_5tsts import get_features_5tsts
get_features_5tsts()

# %% [markdown]
# Y-BALANCE

# %%
from get_features_y_balance import get_features_y_balance
get_features_y_balance()

# %% [markdown]
# JUMP

# %%
from get_features_jump import get_features_jump
get_features_jump()

# %% [markdown]
# MARCH

# %%
from get_features_march import get_features_march
get_features_march()

# %% [markdown]
# GAIT

# %%
from get_features_gait import get_features_gait
get_features_gait()

# %% [markdown]
# GAIT-FAST

# %%
from get_features_gait_fast import get_features_gait_fast
get_features_gait_fast()

# %% [markdown]
# GAIT-PIVOT

# %%
from get_features_gait_pivot import get_features_gait_pivot
get_features_gait_pivot()

# %% [markdown]
# GAIT-TANDEM

# %%
from get_features_gait_tandem import get_features_gait_tandem
get_features_gait_tandem()

# %% [markdown]
# GAIT-BACKWARDS

# %%
from get_features_gait_bwd import get_features_gait_bwd
get_features_gait_bwd()

# %% [markdown]
# GAIT EYES-CLOSED

# %%
from get_features_gait_ec import get_features_gait_ec
get_features_gait_ec()
